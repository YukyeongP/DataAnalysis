# %% [markdown]
# # 동작구 여성안심택배 이용현황

# %%
# !pip install openpyxl
# !pip install xlrd
# Out:
# Requirement already satisfied: openpyxl in c:\users\byk11\anaconda3\lib\site-packages (3.0.4)
# Requirement already satisfied: jdcal in c:\users\byk11\anaconda3\lib\site-packages (from openpyxl) (1.4.1)
# Requirement already satisfied: et-xmlfile in c:\users\byk11\anaconda3\lib\site-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: xlrd in c:\users\byk11\anaconda3\lib\site-packages (1.2.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import folium
import requests
import openpyxl

# %%
# 동작구 안심택배함 주소
dongjak = pd.read_csv('C:/Users/byk11/Downloads/서울특별시_동작구_여성안심택배함_20210928_1632792217118_6445.csv', engine='python')
dongjak = dongjak[['시설명', '소재지도로명주소', '위도', '경도']]

# %%
# 19.1 ~ 20.12 시설명별 년월별 점유율
year=19
month=1
name=[]
df=pd.DataFrame()
df_name=''
for i in range(1,25):
    df_name = 'df_'+str(year)+str(month)
    name.append(df_name)
    name[i-1] = pd.read_excel(filename, header=3, sheet_name=str(year)+"."+str(month), usecols=[2,6])
    
    month=month+1
    
    if(i==12):
        year=year+1
        month=1 

df = pd.DataFrame(name[0])

for i in range(1,24):
    df = pd.merge(df,name[i], on='시설명', how='outer')
df = df.dropna(how='all')

# %%
df
facility_name = df['시설명']

# %%
# 동작문화 복지센터(2020.3 이후로 선별진료소설치로 임시 폐쇄)
df[(df['시설명'] == '동작문화 복지센터') | (df['시설명'] == '동작문화 복지센터_신품')]

# 상도3동 주민센터(2019.4 이후로 신규교체)
df[(df['시설명'] == '상도3동 주민센터') | (df['시설명'] == '상도3동 주민센터(신규교체)')]

# 같은 이름 변경
df['시설명'] = df['시설명'].replace('동작문화 복지센터_신품', '동작문화 복지센터')
df['시설명'] = df['시설명'].replace('상도3동 주민센터(신규교체)', '상도3동 주민센터')
df['시설명'] = df['시설명'].replace('동작 청소년문화의 집 ', '동작 청소년문화의 집')

# %%
df = df.groupby('시설명', as_index=False).sum()
df = pd.DataFrame(df)
df
# Out:
#             시설명  1월          점유율_x  2월          점유율_x  3월          점유율  \
# 0      강남교회 교육관           0.653333           0.510000         0.585000
# 1         다울도서관           0.000000           0.000000         0.000000
# 2   동작 청소년문화의 집           0.378333           0.316667         0.438333
# 3     동작문화 복지센터           0.804000           0.602667         0.853333
# 4     사당노인종합복지관           0.610526           0.507018         0.594737
# 5        사당문화회관           0.877083           0.537500         0.741667
# 6      상도1동주민센터           0.762500           0.614583         0.741667
# 7     상도3동 주민센터           0.914667           0.661333         0.626667
# 8          순만빌딩           0.879487           0.794872         0.871795
# 9    신한은행_숭실대역점           0.000000           0.000000         0.000000
# 10       예그리나주택           0.722807           0.392982         0.622807
# 11  우리은행 동작구청지점           1.008527           0.803101         0.948062
# 12         해피유통           0.228070           0.175439         0.259649
#
#     4월          점유율  5월          점유율  6월          점유율  7월          점유율  \
# 0          0.485000         0.525000         0.461667         0.518333
# 1          0.000000         0.000000         0.000000         0.000000
# 2          0.313333         0.383333         0.296667         0.261667
# 3          0.624000         0.594667         0.506667         0.638667
# 4          0.717544         0.585965         0.519298         0.608772
# 5          0.716667         0.858333         0.822917         0.739583
# 6          0.645833         0.797917         0.558333         0.535417
# 7          0.766667         1.006667         0.865333         0.957333
# 8          0.956410         0.807692         0.766667         0.846154
# 9          0.000000         0.000000         0.000000         0.000000
# 10         0.529825         0.510526         0.503509         0.482456
# 11         0.881395         0.903876         0.717054         0.960465
# 12         0.154386         0.240351         0.214035         0.254386
#
#     8월          점유율  9월          점유율  ...  03월\n점유율  04월\n점유율  05월\n점유율  \
# 0          0.480000         0.616667  ...  0.434635  0.475439  0.468591
# 1          0.000000         0.000000  ...  0.000000  0.000000  0.000000
# 2          0.298333         0.256667  ...  0.281834  0.256140  0.297114
# 3          0.604000         0.720000  ...  0.000000  0.000000  0.002481
# 4          0.596491         0.612281  ...  0.434635  0.515789  0.409168
# 5          0.672917         0.881250  ...  0.561969  0.449123  0.320883
# 6          0.516667         0.537500  ...  0.624788  0.485965  0.495756
# 7          0.908000         0.896000  ...  0.695992  0.603030  0.646139
# 8          0.756410         0.871795  ...  0.621392  0.578947  0.589134
# 9          0.000000         0.000000  ...  0.000000  0.000000  0.000000
# 10         0.607018         0.363158  ...  0.183362  0.171930  0.135823
# 11         0.782171         0.912403  ...  0.746054  0.660993  0.610844
# 12         0.143860         0.168421  ...  0.419355  0.238889  0.198925
#
#     06월\n점유율  07월\n점유율  08월\n점유율  09월\n점유율  10월\n점유율  11월\n점유율  12월\n점유율
# 0   0.514035  0.573854  0.538200  0.509338  0.612903  0.555178  0.555178
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.473684  0.332767  0.373514  0.315789  0.349745  0.314092  0.314092
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.638596  0.507640  0.544992  0.477080  0.517827  0.487267  0.526316
# 5   0.715789  0.584041  0.550085  0.567063  0.611205  0.511036  0.512733
# 6   0.678947  0.582343  0.543294  0.548387  0.585739  0.563667  0.533107
# 7   0.579798  0.691105  0.702835  0.674487  0.702835  0.638319  0.682307
# 8   0.680702  0.507640  0.507640  0.511036  0.544992  0.594228  0.465195
# 9   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.343860  0.225806  0.220713  0.205433  0.241087  0.207131  0.208829
# 11  0.773759  0.734386  0.809883  0.700755  0.803020  0.584763  0.768703
# 12  0.333333  0.220430  0.241935  0.161290  0.241935  0.209677  0.201613
#
# [13 rows x 25 columns]

# %%
print(sorted(df['시설명']))
print('------------------------------')
print(sorted(dongjak['시설명']))

# %%
# 동작문화 복지센터, 해피유통 -> 안심택배함 주소에서 누락 / 현대오일뱅크사당셀프점(안심택배함 주소에만 나와있음)
# 안심택배함위치 데이터프레임과 안심데이터 이용현황 데이터의 시설명 통일시키기
dic = {'강남교회(교육관)':'강남교회 교육관', '동작 청소년문화의 집':'동작청소년문화의집', '상도3동주민센터':'상도3동 주민센터'
       ,'사당어르신종합복지관':'사당노인종합복지관', '신한은행 숭실대역 지점':'신한은행_숭실대역점'}
def replace_all(text, dic):
    for i, j in dic.items():
        text = text.replace(i, j)
    return text

dongjak['시설명'] = replace_all(dongjak['시설명'], dic)
dongjak
# Out:
#             시설명              소재지도로명주소         위도          경도
# 0        신대방해피점   서울특별시 동작구 신대방1나길 26  37.486475  126.907685
# 1      강남교회 교육관       서울특별시 동작구 만양로76  37.510326  126.945101
# 2          순만빌딩     서울특별시 동작구 노량진로169  37.514099  126.944825
# 3   우리은행 동작구청지점   서울특별시 동작구 장승배기로 161  37.512528  126.939942
# 4      상도1동주민센터    서울특별시 동작구 상도로 53길9  37.498101  126.953081
# 5     동작청소년문화의집   서울특별시 동작구 상도로 15바길5  37.504050  126.933246
# 6     상도3동 주민센터     서울특별시 동작구 성대로2길11  37.499126  126.931404
# 7        예그리나주택     서울특별시 동작구 국사봉8길47  37.494719  126.930860
# 8     사당노인종합복지관   서울특별시 동작구 남부순환로2081  37.477017  126.979852
# 9        사당문화회관      서울특별시 동작구 사당로8길9  37.484717  126.969613
# 10  현대오일뱅크사당셀프점     서울특별시 동작구 동작대로 73  37.483120  126.981531
# 11   신한은행_숭실대역점  서울특별시 동작구 상도로 37길 76  37.497602  126.953121
# 12        다울도서관  서울특별시 동작구 사당로20길 132  37.478888  126.973244

# %%
newDF = pd.merge(df, dongjak, on='시설명', how ='outer')

col1=newDF.columns[-3:].to_list()
col2=newDF.columns[1:-3].to_list()
col3=newDF.columns[:1].to_list()
new_col=col3+col1+col2
newDF=newDF[new_col]
newDF
# Out:
# Index(['시설명', '소재지도로명주소', '위도', '경도', '1월          점유율_x', '2월          점유율_x',
#        '3월          점유율', '4월          점유율', '5월          점유율',
#        '6월          점유율', '7월          점유율', '8월          점유율',
#        '9월          점유율', '10월          점유율', '11월          점유율',
#        '12월          점유율', '1월          점유율_y', '2월          점유율_y',
#        '03월\n점유율', '04월\n점유율', '05월\n점유율', '06월\n점유율', '07월\n점유율', '08월\n점유율',
#        '09월\n점유율', '10월\n점유율', '11월\n점유율', '12월\n점유율'],
#       dtype='object')

# %% [markdown]
# # 여성안심택배함 위치 (송파구, 동작구)

# %%
seoul_data = pd.read_csv('C:/Users/byk11/Downloads/서울특별시 여성 안심 택배함(안심이) 설치 장소.csv', engine='python')
seoul_data

# %%
# 송파, 동작만 뽑아 오기
songpa = seoul_data[seoul_data['자치구'] == '송파구']
dongjak = seoul_data[seoul_data['자치구'] == '동작구']

result = pd.concat([songpa,dongjak])

# 인덱스 재정렬
result = result.reset_index(drop=True)
result

# %%
#지도의 중심을 지정하기 위해 위도와 경도의 평균 구하기
result_x = result['WGS x 좌표']
result_y = result['WGS y 좌표']

lat = result['WGS x 좌표'].mean()
long = result['WGS y 좌표'].mean()

m = folium.Map([lat, long], zoom_start = 12, tiles='cartodbpositron')

coords = []
for i in range(len(result)-1):
    x = result_x[i]
    y = result_y[i]
    coords.append([x, y])
    
for i in range(len(coords)):
    folium.Circle(
        location = coords[i],
        radius = 50,
        color = '#ED9253',
        fill = 'crimson',
    ).add_to(m)

#m.save('C:/Users/byk11/Downloads/seoul_map.html')
m

# %% [markdown]
# # CCTV 위치(송파구, 동작구)

# %%
seoul_CCTV_data = pd.read_csv('C:/Users/byk11/Downloads/서울특별시 (안심이) CCTV 설치 현황.csv', engine='python')
seoul_CCTV_data

# %%
songpa_CCTV = seoul_CCTV_data[seoul_CCTV_data['자치구'] == '송파구']
dongjak_CCTV = seoul_CCTV_data[seoul_CCTV_data['자치구'] == '동작구']
CCTV_result = pd.concat([songpa_CCTV,dongjak_CCTV])
CCTV_result

# 인덱스 재정렬
CCTV_result = CCTV_result.reset_index(drop=True)
CCTV_result

# %%
# 결측치 확인
CCTV_result.isnull().sum()

# %%
# 결측치 제거
CCTV_result = CCTV_result.dropna(subset=['WGS x좌표', 'WGS y좌표'])
CCTV_result.isnull().sum()
# 인덱스 재정렬
CCTV_result = CCTV_result.reset_index(drop=True)

CCTV_result

# %%
#지도의 중심을 지정하기 위해 위도와 경도의 평균 구하기
result_x = result['WGS x 좌표']
result_y = result['WGS y 좌표']

CCTV_result_x = CCTV_result['WGS x좌표']
CCTV_result_y = CCTV_result['WGS y좌표']

lat = CCTV_result['WGS x좌표'].mean()
long = CCTV_result['WGS y좌표'].mean()

m = folium.Map([lat, long], zoom_start = 12, tiles='cartodbpositron')

coords = []
coords2 = []

#CCTV 
for i in range(len(CCTV_result)-1):
    x = CCTV_result_x[i]
    y = CCTV_result_y[i]
    coords.append([x, y])
    
for i in range(len(coords)):
    folium.Circle(
        location = coords[i],
        radius = 50,
        color = 'blue',
        fill = 'crimson',
    ).add_to(m)

# 안심택배함 시각화
for i in range(len(result)-1):
    x2 = result_x[i]
    y2 = result_y[i]
    coords2.append([x2, y2])
    
for i in range(len(coords2)):
    folium.Circle(
        location = coords2[i],
        radius = 50,
        color = '#ED9253',
        fill = 'crimson',
    ).add_to(m)
    
#m.save('C:/Users/byk11/Downloads/seoul_map.html')
m

# %% [markdown]
# # 동작구 공공와이파이

# %%
dongjak_wifi = pd.read_csv('C:/Users/byk11/Downloads/서울특별시 동작구 공공와이파이 서비스 위치 정보.csv', engine='python')
dongjak_wifi

# %%
# 결측치 확인
dongjak_wifi.isnull().sum()

# %%
#지도의 중심을 지정하기 위해 위도와 경도의 평균 구하기
wifi_result_x = dongjak_wifi['Y좌표']
wifi_result_y = dongjak_wifi['X좌표']

lat = wifi_result_x.mean()
long = wifi_result_y.mean()

m = folium.Map([lat, long], zoom_start = 12, tiles='cartodbpositron')

coords = []
for i in range(len(dongjak_wifi)-1):
    x = wifi_result_x[i]
    y = wifi_result_y[i]
    coords.append([x, y])
    
for i in range(len(coords)):
    folium.Circle(
        location = coords[i],
        radius = 50,
        color = 'skyblue',
        fill = 'crimson',
    ).add_to(m)

#m.save('C:/Users/byk11/Downloads/seoul_map.html')
m

# %% [markdown]
# # 동작구 안심택배함 이용현황(2021.6-7월)

# %%
seoul_data1 = pd.read_csv('C:/Users/byk11/Downloads/서울특별시 동작구_여성안심택배함 연간 이용 현황_202101.csv', engine='python', encoding='utf-8')
seoul_data2 = pd.read_csv('C:/Users/byk11/Downloads/서울특별시 동작구_여성안심택배함 연간 이용 현황_202102.csv', engine='python', encoding='utf-8')
seoul_data3 = pd.read_csv('C:/Users/byk11/Downloads/서울특별시 동작구_여성안심택배함 연간 이용 현황_202103.csv', engine='python', encoding='utf-8')
seoul_data4 = pd.read_csv('C:/Users/byk11/Downloads/서울특별시 동작구_여성안심택배함 연간 이용 현황_202104.csv', engine='python', encoding='utf-8')

#
seoul_data5 = pd.read_csv('C:/Users/byk11/Downloads/서울특별시 동작구_여성안심택배함 연간 이용 현황_202105.csv', engine='python', encoding='utf-8')
seoul_data5

# %%
seoul_data6 = pd.read_csv('C:/Users/byk11/Downloads/서울특별시 동작구_여성안심택배함 연간 이용 현황_202106.csv', engine='python', encoding='utf-8')
seoul_data6

# %%
seoul_data7 = pd.read_csv('C:/Users/byk11/Downloads/서울특별시 동작구_여성안심택배함 연간 이용 현황_20210728.csv', engine='python', encoding='utf-8')
seoul_data7.isnull().sum()
seoul_data7 = seoul_data7.dropna()
seoul_data7 = seoul_data7.replace('동작문화 복지센터_신품', '동작문화 복지센터')
seoul_data7

# %% [markdown]
# ## 동작구 시설 별 칸수(2021.7)

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15,8))
plt.xticks(rotation = 45 )
sns.barplot(data=seoul_data7, x="시설명", y="칸수")

# %% [markdown]
# ## 전월대비 점유율

# %%
seoul_data7['전월대비'] = seoul_data7['전월대비'].replace(r'%', '', regex=True)
pd.to_numeric(seoul_data7.전월대비)

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15,8))
plt.xticks(rotation = 45 )
sns.barplot(data=seoul_data7, x="시설명", y="전월대비")

# %% [markdown]
# ## 5,6,7월 칸수 비교

# %%
seoul_data5[['시설명', '칸수']]

# %%
dongjak_67 = pd.merge(seoul_data6[['시설명', '칸수']], seoul_data7[['시설명', '칸수']], on = '시설명', how = 'left')
dongjak_67.columns=['시설명','6월칸수', '7월칸수']

dongjak_67

# %%
dongjak_567 = pd.merge(seoul_data5[['시설명', '칸수']], dongjak_67, on = '시설명', how = 'left')
dongjak_567.columns=['시설명','5월칸수', '6월칸수', '7월칸수']

dongjak_567

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
#plt.figure(figsize=(15,8))
#plt.xticks(rotation = 45 )
#sns.barplot(data=dongjak_67, x="시설명", y=[['6월칸수','7월칸수']])

dongjak_567.plot(x="시설명", y=['5월칸수', '6월칸수','7월칸수'], kind="bar",figsize=(9,8))
